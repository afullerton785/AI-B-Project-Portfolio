# %% [markdown]
# # Human Recreation

# %% [markdown]
# This notebook contains the human recreations of the original three images. This notebook intends to explore how humans can interpret objects of cultural heritage, specifically 'Free Kicks at Football', before moving on to a comparison of the difference between AI and human interpretation in the final notebook.

# %% [markdown]
# ### How the Images were Made

# %% [markdown]
# These images were made in collaboration with the community. I messaged multiple of my friends and family and shared the original three illustrations with them all, asking them to give their best effort at recreating them. I recieved multiple recreations for the illustrations on drinking and travelling, for which I chose the ones I deemed the best fit for the project, however I only recieved one recreation of the heading illustration. These were the final three:

# %% [markdown]
# * Important note: These recreations were all created post-gemini generations, and for one the gemini generation had influence on the recreation

# %%
from IPython.display import Image
Image ("Travel_Recreation_Car.jpg")

# %% [markdown]
# (Photo taken by Euan Brady on March 13th 2026, permission to use granted)

# %% [markdown]
# This recreation was done by a Greenock Morton fan who lives in Glasgow, meaning he has a long journey to and from every home game which he does using a car. This recreates the original illustration that was based on the travel to games, which was shown to be done by a horse drawn carriage. This recreation only focuses on one area of travel, which is not entirely representative of the multiple options available in the present. I chose it however as I believe it provides the best parallel to the original illustration, as one could argue that the cars now used to get to games are the natural evolution of what once was the horse drawn carriage.

# %%
from IPython.display import Image
Image ("Drinking_Recreation.jpg")

# %% [markdown]
# (Photo taken by author on April 15th 2026)

# %% [markdown]
# This recreation focused more on the positioning and setting than the travel counterpart. This was caused by Gemini modernisation in which the limbs in the generation were mixed up. For this recreation there were many attempts to ensure that each arm was placed the same as the original illustration, in order to highlight the difference between human and AI recreation, which will be further explored in the final notebook.

# %%
from IPython.display import Image
Image ("Header_Recreation.jpg")

# %% [markdown]
# (Photo taken by Fraser McKay on April 17th 2026, permission to use granted)

# %% [markdown]
# This recreation was done to replicate the header illustration. It was taken prior to a game of five a side football by a group of friends. This was the only submission I recieved for the header illustration, and while it does not perfectly recreate the original image, it provides great points for where human interpretation can differ from AI with its 'imperfections'.

# %% [markdown]
# ###### (All participants provided permission for their photographs to be included)

# %% [markdown]
# Overall, this notebook has documented the translating of a cultural heritage item into modern interpretation through human photography and renditions. It has briefly touched on how each of these recreations are representative of the original illustrations in their own way, with some being more faithful to the source material than others.
