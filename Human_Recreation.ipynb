# %% [markdown]
# # Human Recreation

# %% [markdown]
# This notebook contains the human recreation of the original three images. This notebook intents to explore how humans interpret with objects of cultural heritage, before moving on to a comparison of the difference between AI and human interpretation in the final notebook.

# %% [markdown]
# ###
