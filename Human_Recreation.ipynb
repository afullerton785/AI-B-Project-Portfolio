# %% [markdown]
# # Human Recreation

# %% [markdown]
# This notebook contains the human recreations of the original three images. This notebook intends to explore how humans can interpret objects of cultural heritage, specifically 'Free Kicks at Football', before moving on to a comparison of the difference between AI and human interpretation in the final notebook.

# %% [markdown]
# ### How the Images were Made

# %% [markdown]
# These images were made in collaboration with the community. I messaged multiple of my friends and family and shared the original three illustrations with them all, asking them to give their best effort at recreating them. I recieved multiple recreations for the illustrations on drinking and travelling, for which I chose the ones I deemed the best, however I only recieved one recreation of the heading illustration. These were the final three:

# %%
from IPython.display import Image
Image ("Travel_Recreation_Car.jpg")

# %% [markdown]
# (Photo taken by Euan Brady on March 7th 2026, permission to use granted)

# %%
from IPython.display import Image
Image ("Drinking_Recreation.jpg")

# %% [markdown]
# (Photo taken by author on April 15th 2026)

# %%
from IPython.display import Image
Image ("Header_Recreation.jpg")

# %% [markdown]
# (Photo taken by Fraser McKay on April 17th 2026, permission to use granted)
