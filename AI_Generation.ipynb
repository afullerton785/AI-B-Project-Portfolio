# %% [markdown]
# # Generating the Images #

# %% [markdown]
# To create my modernised images from the illustrations in the book, I consulted Google Gemini. I chose Gemini over other alternatives after some testing of other programmes such as ChatGPT, ArtBreeder, and MetaAI. I used Gemini over these options beacuse it was the only programme that could accurately maintain the comic feel of the original images, whilst bringing them forward into the modern day.

# %%
from IPython.display import Image
Image ("Gemini_Travel_Page.jpg")

# %% [markdown]
# (Google Gemini, created  March 10 2026)

# %%
from IPython.display import Image
Image ("Gemini_Drink.jpg")

# %% [markdown]
# (Google Gemini, created  March 10 2026)

# %%
from IPython.display import Image
Image ("Gemini_Header.jpg")

# %% [markdown]
# (Google Gemini, created  March 10 2026)

# %% [markdown]
# These were my finalised results from Gemini. They work really well in bringing the ideas from the original illustrations and bringing them into the modern day. I particularly like the transport one as it is reflective of the multitude of transport options in the modern day, in comparison to the sole horse drawn carriage from the original. As is common with AI however
